# %% [markdown]
# # Data Preparation and Advanced Model Evaluation

# %% [markdown]
# ## Agenda
#
# **Data preparation**
#
# - Handling missing values
# - Handling categorical features (review)
#
# **Advanced model evaluation**
#
# - ROC curves and AUC
# - Bonus: ROC curve is only sensitive to rank order of predicted probabilities
# - Cross-validation

# %% [markdown]
# ## Part 1: Handling missing values

# %% [markdown]
# scikit-learn models expect that all values are **numeric** and **hold meaning**. Thus, missing values are not allowed by scikit-learn.

# %%
# read the Titanic training data
import pandas as pd
path = '../data/'
url = path + 'train.csv'
titanic = pd.read_csv(url, index_col='PassengerId')
titanic.shape
# Out:
# (891, 11)

# %%
# check for missing values
titanic.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %% [markdown]
# One possible strategy is to **drop missing values**:

# %%
# drop rows with any missing values
titanic.dropna().shape
# Out:
# (183, 11)

# %%
titanic.shape
# Out:
# (891, 11)

# %%
# drop rows where Age is missing
titanic[titanic.Age.notnull()].shape
# Out:
# (714, 11)

# %% [markdown]
# Sometimes a better strategy is to **impute missing values**:

# %%
# mean Age
titanic.Age.mean()
# Out:
# 29.69911764705882

# %%
# median Age
titanic.Age.median()
# Out:
# 28.0

# %%
# most frequent Age
titanic.Age.mode()
# Out:
# 0    24.0
# dtype: float64

# %%
# fill missing values for Age with the median age
titanic.Age.fillna(titanic.Age.median(), inplace=True)
titanic.shape
# Out:
# (891, 11)

# %%
# read the Titanic test data
import pandas as pd
path = '../data/'
url = path + 'test.csv'
titanic_test = pd.read_csv(url, index_col='PassengerId')
titanic_test.shape
# Out:
# (418, 10)

# %%
# check for missing values
titanic_test.isnull().sum()
# Out:
# Pclass        0
# Name          0
# Sex           0
# Age          86
# SibSp         0
# Parch         0
# Ticket        0
# Fare          1
# Cabin       327
# Embarked      0
# dtype: int64

# %%
titanic_test.Age.fillna(titanic_test.Age.median(), inplace=True)
titanic_test.Fare.fillna(titanic_test.Fare.median(), inplace=True)
titanic_test.shape
# Out:
# (418, 14)

# %% [markdown]
# Another strategy would be to build a **KNN model** just to impute missing values. How would we do that?
#
# If values are missing from a categorical feature, we could treat the missing values as **another category**. Why might that make sense?
#
# How do we **choose** between all of these strategies?

# %% [markdown]
# ## Part 2: Handling categorical features (Review)

# %% [markdown]
# How do we include a categorical feature in our model?
#
# - **Ordered categories:** transform them to sensible numeric values (example: small=1, medium=2, large=3)
# - **Unordered categories:** use dummy encoding (0/1)

# %%
titanic.head(10)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male  28.0
# ...

# %%
# Create and encode Female feature
titanic['Female'] = titanic.Sex.map({'male':0, 'female':1})
titanic_test['Female'] = titanic_test.Sex.map({'male':0, 'female':1})

# %%
titanic.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  Female
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S       0
# 2                1      0          PC 17599  71.2833   C85        C       1
# ...

# %%
# create a DataFrame of dummy variables for Embarked
embarked_dummies = pd.get_dummies(titanic.Embarked, prefix='Embarked')
embarked_dummies.drop(embarked_dummies.columns[0], axis=1, inplace=True)

# concatenate the original DataFrame and the dummy DataFrame
titanic = pd.concat([titanic, embarked_dummies], axis=1)

# %%
# create a DataFrame of dummy variables for Embarked
embarked_dummies = pd.get_dummies(titanic_test.Embarked, prefix='Embarked')
embarked_dummies.drop(embarked_dummies.columns[0], axis=1, inplace=True)

# concatenate the original DataFrame and the dummy DataFrame
titanic_test = pd.concat([titanic_test, embarked_dummies], axis=1)

# %%
titanic.head(1)
# Out:
#              Survived  Pclass                     Name   Sex   Age  SibSp  \
# PassengerId
# 1                   0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#              Parch     Ticket  Fare Cabin Embarked  Female  Embarked_Q  \
# PassengerId
# 1                0  A/5 21171  7.25   NaN        S       0         0.0
#
#              Embarked_S
# PassengerId
# 1                   1.0

# %% [markdown]
# - How do we **interpret** the encoding for Embarked?
# - Why didn't we just encode Embarked using a **single feature** (C=0, Q=1, S=2)?
# - Does it matter which category we choose to define as the **baseline**?
# - Why do we only need **two dummy variables** for Embarked?

# %%
# define X and y
feature_cols = ['Pclass',  'Age', 'Female',  'Embarked_S',  'SibSp']
X = titanic[feature_cols]
y = titanic.Survived

# train/test split
#from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# train a logistic regression model
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(C=1e9)
logreg.fit(X_train, y_train)

# make predictions for testing set
y_pred_class = logreg.predict(X_test)

# calculate testing accuracy
from sklearn import metrics
print metrics.accuracy_score(y_test, y_pred_class)
# Out:
# 0.807174887892

# %% [markdown]
# ## Part 3: ROC curves and AUC

# %%
# predict probability of survival
y_pred_prob = logreg.predict_proba(X_test)[:, 1]
#print(y_pred_prob)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 14

# %%
# plot ROC curve
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred_prob)
plt.plot(fpr, tpr)
plt.plot(fpr, thresholds)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
#print(metrics.roc_curve(y_test, y_pred_prob))
#print thresholds

# %%
# calculate AUC
print metrics.roc_auc_score(y_test, y_pred_prob)
# Out:
# 0.840789473684

# %% [markdown]
# Seeing the ROC curve and calculate AUC allows you to see the quality of the model and in comparison to other models.
#
# Once satisfied with the estimator and parameter choices, you choose the threshold that best **balances sensitivity and specificity** based on the level of need to favor one over the other.

# %%
# histogram of predicted probabilities grouped by actual response value
df = pd.DataFrame({'probability':y_pred_prob, 'actual':y_test})
df.hist(column='probability', by='actual', sharex=True, sharey=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000000C3BE550>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000000C3A82B0>], dtype=object)

# %% [markdown]
# What would have happened if you had used **y_pred_class** instead of **y_pred_prob** when drawing the ROC curve or calculating AUC?

# %%
# ROC curve using y_pred_class - WRONG!
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred_class)
plt.plot(fpr, tpr)

# %%
# AUC using y_pred_class - WRONG!
print metrics.roc_auc_score(y_test, y_pred_class)
# Out:
# 0.799465460526

# %% [markdown]
# If you use **y_pred_class**, it will interpret the zeros and ones as predicted probabilities of 0% and 100%.

# %% [markdown]
# ## Bonus: ROC curve is only sensitive to rank order of predicted probabilities

# %%
# print the first 10 predicted probabilities
y_pred_prob[:10]
# Out:
# array([ 0.84499503,  0.07452708,  0.85089451,  0.62517563,  0.87679784,
#         0.09611295,  0.13614005,  0.90132984,  0.61102779,  0.62517563])

# %%
# take the square root of predicted probabilities (to make them all bigger)
import numpy as np
y_pred_prob_new = np.sqrt(y_pred_prob)

# print the modified predicted probabilities
y_pred_prob_new[:10]
# Out:
# array([ 0.91923611,  0.27299648,  0.92243944,  0.79068049,  0.93637484,
#         0.31002088,  0.36897161,  0.94938393,  0.78168266,  0.79068049])

# %%
# histogram of predicted probabilities has changed
df = pd.DataFrame({'probability':y_pred_prob_new, 'actual':y_test})
df.hist(column='probability', by='actual', sharex=True, sharey=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000000A93F9E8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000000AB36C18>], dtype=object)

# %%
# ROC curve did not change
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred_prob_new)
plt.plot(fpr, tpr)

# %%
# AUC did not change
print metrics.roc_auc_score(y_test, y_pred_prob_new)
# Out:
# 0.838692434211

# %% [markdown]
# ## Part 4: Cross-validation

# %%
# calculate cross-validated AUC
from sklearn.cross_validation import cross_val_score
cross_val_score(logreg, X, y, cv=10, scoring='roc_auc').mean()
# Out:
# 0.84782357185298363

# %%
# Evaluate adding other features.  Add Fare to the model
feature_cols = ['Pclass',  'Age', 'Female',  'Embarked_S',  'SibSp']
X = titanic[feature_cols]

# recalculate AUC
cross_val_score(logreg, X, y, cv=10, scoring='roc_auc').mean()
# Out:
# 0.85554321930792521

# %%
# Train using the entire dataset
X_train = X
y_train = y

X_test = titanic_test[feature_cols]

# train a logistic regression model
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(C=1e9)
logreg.fit(X_train, y_train)

titanic['y_pred_class'] = logreg.predict(X_train)
titanic['y_pred_prob'] = logreg.predict_proba(X_train)[:, 1]

# make predictions for testing set
titanic_test['Survived'] = logreg.predict(X_test)

# concatenate the original DataFrame and the dummy DataFrame
#titanic_test = pd.concat([titanic_test, y_pred_class], axis=1)
titanic_test.head()

path = '../data/'
url = path + 'submit.csv'
titanic_test.to_csv(columns = ['Survived'], path_or_buf = url)

# %%
#Bonus: Create a hypothetical passenger and make a prediction with the best model

# %% [markdown]
# Run the Logistic Regresssion Model on the Kaggle Test dataset

# %%
titanic[(titanic.Survived != titanic.y_pred_class) & (titanic.y_pred_prob > .75)]
# Out:
#              Survived  Pclass  \
# PassengerId
# 42                  0       2
# 115                 0       3
# 178                 0       1
# 200                 0       2
# 206                 0       3
# 298                 0       1
# 313                 0       2
# 358                 0       2
# 499                 0       1
# 655                 0       3
# 703                 0       3
# 853                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 42           Turpin, Mrs. William John Robert (Dorothy Ann ...  female  27.0
# 115                                      Attalah, Miss. Malake  female  17.0
# 178                                 Isham, Miss. Ann Elizabeth  female  50.0
# 200                     Yrois, Miss. Henriette ("Mrs Harbeck")  female  24.0
# 206                                 Strom, Miss. Telma Matilda  female   2.0
# ...

# %% [markdown]
# Remember to use the training data to update test data where there are matches - update, there are no matches!

# %%
feature_cols = ['Pclass',  'Age', 'Female',  'Embarked_S',  'SibSp', 'Fare', 'Parch']
X_train = titanic[feature_cols]
y_train = titanic.Survived

# import KNN class we need from scikit-learnQ
from sklearn.neighbors import KNeighborsClassifier
# instantiate the estimator with K=6
knn = KNeighborsClassifier(n_neighbors=2, weights='distance')
# run a knn.fit on the data to build the model
knn.fit(X_train, y_train)

titanic['y_pred_class_knn']=knn.predict(X_train)
print metrics.accuracy_score(titanic.Survived, titanic.y_pred_class_knn)
print knn.score(X_train, y_train)

X_test = titanic_test[feature_cols]

# make predictions for testing set
titanic_test['Survived'] = knn.predict(X_test)

path = '../data/'
url = path + 'submit.csv'
titanic_test.to_csv(columns = ['Survived'], path_or_buf = url, header=False)
# Out:
# 0.978675645342
# 0.978675645342

# %%
titanic_test
# Out:
#              Pclass                                               Name  \
# PassengerId
# 892               3                                   Kelly, Mr. James
# 893               3                   Wilkes, Mrs. James (Ellen Needs)
# 894               2                          Myles, Mr. Thomas Francis
# 895               3                                   Wirz, Mr. Albert
# 896               3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 897               3                         Svensson, Mr. Johan Cervin
# 898               3                               Connolly, Miss. Kate
# 899               2                       Caldwell, Mr. Albert Francis
# 900               3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 901               3                            Davies, Mr. John Samuel
# 902               3                                   Ilieff, Mr. Ylio
# 903               1                         Jones, Mr. Charles Cresson
# ...

# %%
titanic[(titanic.Survived != titanic.y_pred_class_knn) ]
# Out:
#              Survived  Pclass                                           Name  \
# PassengerId
# 18                  1       2                   Williams, Mr. Charles Eugene
# 22                  1       2                          Beesley, Mr. Lawrence
# 37                  1       3                               Mamee, Mr. Hanna
# 108                 1       3                         Moss, Mr. Albert Johan
# 188                 1       1  Romaine, Mr. Charles Hallace ("Mr C Rolmane")
# 221                 1       3                 Sunderland, Mr. Victor Francis
# 227                 1       2                      Mellors, Mr. William John
# 265                 0       3                             Henry, Miss. Delia
# 268                 1       3                       Persson, Mr. Ernst Ulrik
# 284                 1       3                     Dorking, Mr. Edward Arthur
# 289                 1       2                           Hosono, Mr. Masabumi
# ...

# %%
titanic_merge=pd.concat([titanic_test, titanic], axis = 1, join_axes=[titanic_test.index])
titanic_merge
# Out:
#              Pclass                                               Name  \
# PassengerId
# 892               3                                   Kelly, Mr. James
# 893               3                   Wilkes, Mrs. James (Ellen Needs)
# 894               2                          Myles, Mr. Thomas Francis
# 895               3                                   Wirz, Mr. Albert
# 896               3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 897               3                         Svensson, Mr. Johan Cervin
# 898               3                               Connolly, Miss. Kate
# 899               2                       Caldwell, Mr. Albert Francis
# 900               3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 901               3                            Davies, Mr. John Samuel
# 902               3                                   Ilieff, Mr. Ylio
# 903               1                         Jones, Mr. Charles Cresson
# ...

# %%
titanic_test.shape
# Out:
# (418, 14)
